# %% [markdown]
# 1. pip install beautifulsoup4
# 2. pip install bs4
# 3. pip install requests

# %%
pip install BeautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install BeautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# python libraries
#
# 1) beautifulsoup4
# 2) Selenium
# 4) Scrapy

# %%
from bs4 import BeautifulSoup
import requests

# %%
url ='https://realpython.github.io/fake-jobs/'
request = requests.get(url)
request
# Out:
# <Response [200]>

# %%
info = BeautifulSoup(request.content, 'html.parser')
info
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Fake Python</title>
# <link href="https://cdn.jsdelivr.net/npm/bulma@0.9.2/css/bulma.min.css" rel="stylesheet"/>
# </head>
# <body>
# <section class="section">
# <div class="container mb-5">
# <h1 class="title is-1">
#         Fake Python
#       </h1>
# <p class="subtitle is-3">
#         Fake Jobs for Your Web Scraping Journey
#       </p>
# </div>
# <div class="container">
# <div class="columns is-multiline" id="ResultsContainer">
# <div class="column is-half">
# <div class="card">
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Senior Python Developer</h2>
# ...

# %%
title = info.find(class_='title is-1')
title.text
# Out:
# '\n        Fake Python\n      '

# %%
description = info.find(class_='subtitle is-3')
description.text
# Out:
# '\n        Fake Jobs for Your Web Scraping Journey\n      '

# %%
title = info.find(class_='title is-1')
title.text.strip()
# Out:
# 'Fake Python'

# %%
# container mb-5
# id

# %%
div = info.find(id='ResultsContainer')
div.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\nSenior Python Developer\nPayne, Roberts and Davis\n\n\n\n\n        Stewartbury, AA\n      \n\n2021-04-08\n\n\n\nLearn\nApply\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nEnergy engineer\nVasquez-Davidson\n\n\n\n\n        Christopherville, AA\n      \n\n2021-04-08\n\n\n\nLearn\nApply\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLegal executive\nJackson, Chambers and Levy\n\n\n\n\n        Port Ericaburgh, AA\n      \n\n2021-04-08\n\n\n\nLearn\nApply\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFitness centre manager\nSavage-Bradley\n\n\n\n\n        East Seanview, AP\n      \n\n2021-04-08\n\n\n\nLearn\nApply\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nProduct manager\nRamirez Inc\n\n\n\n\n        North Jamieview, AP\n      \n\n2021-04-08\n\n\n\nLearn\nApply\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMedical technical officer\nRogers-Yates\n\n\n\n\n        Davidville, AP\n      \n\n2021-04-08\n\n\n\nLearn\nApply\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPhysiological scientist\nKramer-Klein\n\n\n\n\n        South Christopher, AE\n      \n\n2021-04-08\n\
# ...

# %%
jobs = info.find_all(class_='column is-half')
jobs
# Out:
# [<div class="column is-half">
#  <div class="card">
#  <div class="card-content">
#  <div class="media">
#  <div class="media-left">
#  <figure class="image is-48x48">
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
#  </figure>
#  </div>
#  <div class="media-content">
#  <h2 class="title is-5">Senior Python Developer</h2>
#  <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
#  </div>
#  </div>
#  <div class="content">
#  <p class="location">
#          Stewartbury, AA
#        </p>
#  <p class="is-small has-text-grey">
#  <time datetime="2021-04-08">2021-04-08</time>
#  </p>
#  </div>
#  <footer class="card-footer">
#  <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
#  <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html" target="_blank">Apply</a>
#  </footer>
#  </div>
#  </div>
# ...

# %%
for job in jobs:
    print(job.text.strip())


# job_title
# subtitle
# location
# date
# Out:
# Senior Python Developer
# Payne, Roberts and Davis
#
#
#
#
#         Stewartbury, AA
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Energy engineer
# Vasquez-Davidson
#
#
#
#
#         Christopherville, AA
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Legal executive
# Jackson, Chambers and Levy
#
#
#
#
#         Port Ericaburgh, AA
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Fitness centre manager
# Savage-Bradley
#
#
#
#
#         East Seanview, AP
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Product manager
# Ramirez Inc
#
#
#
#
#         North Jamieview, AP
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Medical technical officer
# Rogers-Yates
#
#
#
#
#         Davidville, AP
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Physiological scientist
# Kramer-Klein
#
#
#
#
#         South Christopher, AE
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Textile designer
# Meyers-Johnson
#
#
#
#
#         Port Jonathan, AE
#
#
# 2021-04-08
#
#
#
# Learn
# Apply
# Television floor manager
# Hughes-Williams
#
#
#
#
# ...

# %%
div_data = info.find(class_='column is-half')
div_data
# Out:
# <div class="column is-half">
# <div class="card">
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Senior Python Developer</h2>
# <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Stewartbury, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html" target="_blank">Apply</a>
# </footer>
# </div>
# </div>
# </div>

# %%
jobs = info.find_all(class_='column is-half')
jobs
# Out:
# [<div class="column is-half">
#  <div class="card">
#  <div class="card-content">
#  <div class="media">
#  <div class="media-left">
#  <figure class="image is-48x48">
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
#  </figure>
#  </div>
#  <div class="media-content">
#  <h2 class="title is-5">Senior Python Developer</h2>
#  <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
#  </div>
#  </div>
#  <div class="content">
#  <p class="location">
#          Stewartbury, AA
#        </p>
#  <p class="is-small has-text-grey">
#  <time datetime="2021-04-08">2021-04-08</time>
#  </p>
#  </div>
#  <footer class="card-footer">
#  <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
#  <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html" target="_blank">Apply</a>
#  </footer>
#  </div>
#  </div>
# ...

# %%
jobs_data =[]
for job in jobs:
    # print(job)
    job_title = job.find(class_='title is-5')
    subtitle = job.find(class_='subtitle is-6 company')
    location = job.find(class_='location')
    date_job = job.find(class_='is-small has-text-grey')
    data = [job_title.text,subtitle.text,location.text,date_job.text]
    jobs_data.append(data)
    # print(job_title.text,subtitle.text,location.text,date_job.text)
    # break

# %% [markdown]
# ### Web Scraping Exercise with BeautifulSoup
# https://babynestboutique.com/collections/fashion

# %%
jobs_data
# Out:
# [['Senior Python Developer',
#   'Payne, Roberts and Davis',
#   '\n        Stewartbury, AA\n      ',
#   '\n2021-04-08\n'],
#  ['Energy engineer',
#   'Vasquez-Davidson',
#   '\n        Christopherville, AA\n      ',
#   '\n2021-04-08\n'],
#  ['Legal executive',
#   'Jackson, Chambers and Levy',
#   '\n        Port Ericaburgh, AA\n      ',
#   '\n2021-04-08\n'],
#  ['Fitness centre manager',
#   'Savage-Bradley',
#   '\n        East Seanview, AP\n      ',
#   '\n2021-04-08\n'],
#  ['Product manager',
#   'Ramirez Inc',
#   '\n        North Jamieview, AP\n      ',
#   '\n2021-04-08\n'],
#  ['Medical technical officer',
#   'Rogers-Yates',
#   '\n        Davidville, AP\n      ',
#   '\n2021-04-08\n'],
#  ['Physiological scientist',
#   'Kramer-Klein',
#   '\n        South Christopher, AE\n      ',
#   '\n2021-04-08\n'],
#  ['Textile designer',
#   'Meyers-Johnson',
#   '\n        Port Jonathan, AE\n      ',
#   '\n2021-04-08\n'],
#  ['Television floor manager',
#   'Hughes-Williams',
# ...

# %%
new_requests = requests.get('https://babynestboutique.com/collections/fashion')

# %%
soup = BeautifulSoup(new_requests.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="" name="theme-color"/>
# <link href="https://babynestboutique.com/collections/fashion" rel="canonical"/>
# <link canonical-shop-url="https://babynestboutique.com/" href="https://babynestboutique.com/collections/fashion" rel="canonical"/><link href="//babynestboutique.com/cdn/shop/files/icon_32x32.png?v=1706101120" rel="shortcut icon" type="image/png"/><link crossorigin="" href="https://cdn.shopify.com" rel="preconnect"/>
# <title>Fashion: Stylish Picks for Your Little Ones | Baby Nest Boutique  – Babynest Boutique</title><meta content="Explore trendy fashion for babies at Baby Nest Boutique! Discover stylish picks and adorable outfits to keep your little ones looking fabulous." name="description"/>
# ...

# %%
first_link = soup.find(class_='card-title link-underline card-title-ellipsis')
link = 'https://babynestboutique.com' + first_link.get('href')
link
# Out:
# 'https://babynestboutique.com/products/shorts-for-boys-navy-blue'

# %%
links = soup.find_all(class_='card-title link-underline card-title-ellipsis')
for link in links:
    link = 'https://babynestboutique.com' + link.get('href')
    print(link)
# Out:
# https://babynestboutique.com/products/shorts-for-boys-navy-blue
# https://babynestboutique.com/products/shorts-for-boys-sky-blue-copy
# https://babynestboutique.com/products/shorts-for-boys-black-copy
# https://babynestboutique.com/products/shorts-for-boys-navy-blue
# https://babynestboutique.com/products/shorts-for-boys-sky-blue-copy
# https://babynestboutique.com/products/shorts-for-boys-black-copy
# https://babynestboutique.com/products/shorts-for-boys-navy-blue
# https://babynestboutique.com/products/shorts-for-boys-sky-blue-copy
# https://babynestboutique.com/products/shorts-for-boys-black-copy
# https://babynestboutique.com/products/wild-one-half-sleeves-t-shirt-for-kids-dark-green-sbt-360
# https://babynestboutique.com/products/parrot-in-the-pot-half-sleeves-t-shirts-for-kids-light-pink-sbt-369
# https://babynestboutique.com/products/baby-half-romper-friends-hello-white
# https://babynestboutique.com/products/girl-power-half-sleeves-t-shirts-for-kids-purple-sbt-367
# ...

# %%
new_requests = requests.get('https://babynestboutique.com/collections/fashion')
soup = BeautifulSoup(new_requests.content, 'html.parser')
# soup

# %%
'card-title link-underline card-title-ellipsis'
links = soup.find_all(class_='card-title link-underline card-title-ellipsis')
for link in links:
    # link = 'https://babynestboutique.com' + link.get('href')
    # print(link)
    


    first_link = soup.find(class_='card-title link-underline card-title-ellipsis')
    link = 'https://babynestboutique.com' + first_link.get('href')
    print(link)
    break
# Out:
# https://babynestboutique.com/products/shorts-for-boys-navy-blue

# %%
# links = soup.find_all(class_='card-title link-underline card-title-ellipsis')
# for link in links:


first_link = soup.find(class_='card-title link-underline card-title-ellipsis')
link = 'https://babynestboutique.com' + first_link.get('href')
print(link)
# Out:
# https://babynestboutique.com/products/shorts-for-boys-navy-blue

# %%
new_requests = requests.get("https://babynestboutique.com/products/shorts-for-boys-sky-blue-copy")
soup = BeautifulSoup(new_requests.content, 'html.parser')

u = "https://babynestboutique.com/products/shorts-for-boys-sky-blue-copy"
for i in u:
    # jobs_data =[]

    # print(i)
    job_title = i.find(class_='money buckscc-money')
    # subtitle = i.find(class_='subtitle is-6 company')
    # location = u.find(class_='location')
    # date_job = u.find(class_='is-small has-text-grey')
    # data = [job_title.text,subtitle.text,location.text,date_job.text]
    # jobs_data.append(data)
    # print(job_title.text,subtitle.text,location.text,date_job.text)
    print(job_title.text)
    # print(subtitle.text)
    # print(location.text)
    # print(date_job.text)
    # print(data)
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 9
#       4 u = "https://babynestboutique.com/products/shorts-for-boys-sky-blue-copy"
#       5 for i in u:
#       6     # jobs_data =[]
#       7
#       8     # print(i)
# ----> 9     job_title = i.find(class_='money buckscc-money')
#      10     # subtitle = i.find(class_='subtitle is-6 company')
#      11     # location = u.find(class_='location')
#      12     # date_job = u.find(class_='is-small has-text-grey')
#      13     # data = [job_title.text,subtitle.text,location.text,date_job.text]
#      14     # jobs_data.append(data)
#      15     # print(job_title.text,subtitle.text,location.text,date_job.text)
#      16     print(job_title.text)
#
# TypeError: str.find() takes no keyword arguments

# %%
import requests
from bs4 import BeautifulSoup

# Example URL
url = "https://babynestboutique.com/products/shorts-for-boys-sky-blue-copy"

# Make a request to the website
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the subtitle element
subtitle = soup.find(class_='money buckscc-money')

# Check if the subtitle is found and print it
if subtitle:
    print(subtitle.text)
else:
    print("Subtitle not found.")
# Out:
# Subtitle not found.

# %% [markdown]
# ### Web Scraping Exercise with BeautifulSoup
# ----->

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")
# soups = BeautifulSoup("html.parser")
# print(soup)
# print(soups)
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    Some
#    <b>
#     bad
#     <i>
#      HTML
#     </i>
#    </b>
#   </p>
#  </body>
# </html>

# %%
soup.find(text="bad")
# Out:
# C:\Users\haier\AppData\Local\Temp\ipykernel_3176\918349966.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soup.find(text="bad")
# 'bad'

# %%
print(soup.p)
print(soup.b)
print(soup.i)
# Out:
# <p>Some<b>bad<i>HTML</i></b></p>
# <b>bad<i>HTML</i></b>
# <i>HTML</i>

# %%
soup = BeautifulSoup("<tag1>Some<tag2/>bad<tag3>XML", "xml")
print(soup)
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <tag1>Some<tag2/>bad<tag3>XML</tag3></tag1>
# <?xml version="1.0" encoding="utf-8"?>
# <tag1>
#  Some
#  <tag2/>
#  bad
#  <tag3>
#   XML
#  </tag3>
# </tag1>

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
print(soup.a)
print(soup.find_all("a"))
print(soup.find(id="link2"))
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
soup.title
# <title>The Dormouse's story</title>

soup.title.name
# u'title'

soup.title.string
# u'The Dormouse's story'

soup.title.parent.name
# u'head'

soup.p
# <p class="title"><b>The Dormouse's story</b></p>

soup.p['class']
# u'title'

soup.a
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

soup.find_all('a')
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

soup.find(id="link3")
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
# print(soup.find_all("a"))
for link in soup.find_all("a"):
    print(link.get("href"))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
print(soup.text)
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
from bs4 import BeautifulSoup

try:
    with open("index.html") as fp:
        soup = BeautifulSoup(fp, 'html.parser')
    print(soup.prettify())  # To print the parsed HTML
except FileNotFoundError:
    print("The file 'index.html' was not found. Please check the file path and try again.")


print(soup.prettify())  # To print the parsed HTML
# from bs4 import BeautifulSoup

# with open("index.html") as fp:
#     soup = BeautifulSoup(fp, 'html.parser')

# soup = BeautifulSoup("<html>a web page</html>", 'html.parser')
# Out:
# The file 'index.html' was not found. Please check the file path and try again.
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
print(BeautifulSoup("<html><head></head><body>Sacr&eacute; bleu!</body></html>", "html.parser"))
# <html><head></head><body>Sacré bleu!</body></html>
# Out:
# <html><head></head><body>Sacré bleu!</body></html>
